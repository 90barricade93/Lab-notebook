# %% [markdown]
# # AI apprentice Lab 1 - Exploratory Data Analysis
#
# ### Tasks
# - Load dataset into Python
# - Print out the dataset head and data types
# - Obtain value counts for each feature in the dataset
# - Derive statistical information from the dataset
# - Visualize dataset distribution by quality
# - Visualize dataset distribution by features
#
# ## Introduction
#
# in this excerise we will perform EDA on the [wine dataset]
#
# Your assignment for this exercise is to practice working with datasets in Python, conduct data analysis, and use visualization tools.

# %% [markdown]
# ## Start

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task Load dataset into Python

# %%
WijnRood = pd.read_csv('WDS\winequality-red.csv', delimiter=';')
WijnWit = pd.read_csv('WDS\winequality-white.csv', delimiter=';')

# %% [markdown]
# ## Task Print out the dataset head and data types

# %%
Wtotaal = pd.concat([WijnRood, WijnWit])
Wtotaal.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# obtain datatypes
print("Data types:\n\n" + str(Wtotaal.dtypes))
# Out:
# Data types:
#
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# ## Task Obtain value counts for each feature in the dataset

# %%
# obtain value counts per feature
print("Alcohol:\n\n", Wtotaal['alcohol'].value_counts(), "\n\n",
      "Sulphates:\n\n", Wtotaal['sulphates'].value_counts(), "\n\n",
      "Density:\n\n", Wtotaal['density'].value_counts(), "\n\n", 
      "pH:\n\n", Wtotaal['pH'].value_counts(), "\n\n",
      "Quality:\n\n", Wtotaal['quality'].value_counts(), "\n\n",
      "total sulfur dioxide:\n\n", Wtotaal['total sulfur dioxide'].value_counts(), "\n\n",
      "free sulfur dioxide:\n\n", Wtotaal['free sulfur dioxide'].value_counts(), "\n\n",
      "residual sugar:\n\n", Wtotaal['residual sugar'].value_counts(), "\n\n",
      "citric acid:\n\n", Wtotaal['citric acid'].value_counts(), "\n\n",
      "chlorides:\n\n", Wtotaal['chlorides'].value_counts(), "\n\n",
      "volatile acidity:\n\n", Wtotaal['volatile acidity'].value_counts(), "\n\n",
      "fixed acidity:\n\n", Wtotaal['fixed acidity'].value_counts(), "\n\n",
      sep='')
# Out:
# Alcohol:
#
# 9.500000     367
# 9.400000     332
# 9.200000     271
# 10.000000    229
# 10.500000    227
#             ...
# 11.366667      1
# 9.750000       1
# 11.350000      1
# 14.050000      1
# 12.050000      1
# Name: alcohol, Length: 111, dtype: int64
#
# Sulphates:
#
# 0.50    276
# 0.46    243
# 0.54    235
# 0.44    232
# 0.38    214
#        ...
# 1.11      1
# 1.12      1
# 1.61      1
# 1.09      1
# 0.23      1
# Name: sulphates, Length: 111, dtype: int64
#
# Density:
#
# 0.99760    69
# 0.99720    69
# 0.99800    64
# 0.99200    64
# 0.99280    63
#            ..
# 0.99852     1
# 0.99833     1
# 0.98853     1
# 0.99589     1
# 0.98941     1
# Name: density, Length: 998, dtype: int64
#
# pH:
#
# 3.16    200
# 3.14    193
# 3.22    185
# 3.20    176
# 3.15    170
#        ...
# 2.77      1
# 2.72      1
# 3.81      1
# 3.82      1
# 2.82      1
# Name: pH, Length: 108, dtype: int64
#
# Quality:
#
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# ...

# %% [markdown]
# ## Task Visualize dataset distribution by quality

# %%
# show value distribution
Wtotaal.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
# Visualize dataset distribution by quality 
plt.figure(figsize=(5,5))
plt.scatter(Wtotaal['quality'], Wtotaal['alcohol'])
plt.xlabel('Quality')
plt.ylabel('VOL %')
# Out:
# Text(0, 0.5, 'VOL %')

# %% [markdown]
# ## Task Visualize dataset distribution by features

# %%
# Visualize dataset distribution from all features with space between them in histogram
Wtotaal.hist(figsize=(20,20))
plt.autoscale()
plt.show()

# %% [markdown]
# Assignment done by: Ray
